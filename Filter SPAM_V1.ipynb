# %%
import pandas as pd
import numpy as np
import re
import string

import nltk
from nltk.corpus import stopwords
from pattern.es import lemma
from nltk.tokenize import sent_tokenize, word_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer,TfidfTransformer

from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score

from xgboost import XGBClassifier
import matplotlib.pyplot as plt

import joblib

# %%
psy=pd.read_csv("Data/YouTubeSpamCollection_FromUCI/Youtube01-Psy.csv")
psy.head()
# Out:
#                                     COMMENT_ID            AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU         Julius NM
# 1  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 2  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 3          z13jhp0bxqncu512g22wvzkasxmvvzjaz04   ElNino Melendez
# 4          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw            GsMega
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 2  2013-11-08T17:34:21             just for test I have to say murdev.com
# 3  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 4  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
kp=pd.read_csv("Data/YouTubeSpamCollection_FromUCI/Youtube02-KatyPerry.csv")
kp.head()
# Out:
#                               COMMENT_ID        AUTHOR                 DATE  \
# 0      z12pgdhovmrktzm3i23es5d5junftft3f   lekanaVEVO1  2014-07-22T15:27:50
# 1    z13yx345uxepetggz04ci5rjcxeohzlrtf4      Pyunghee  2014-07-27T01:57:16
# 2  z12lsjvi3wa5x1vwh04cibeaqnzrevxajw00k    Erica Ross  2014-07-27T02:51:43
# 3    z13jcjuovxbwfr0ge04cev2ipsjdfdurwck  Aviel Haimov  2014-08-01T12:27:48
# 4  z13qybua2yfydzxzj04cgfpqdt2syfx53ms0k    John Bello  2014-08-01T21:04:03
#
#                                              CONTENT  CLASS
# 0  i love this so much. AND also I Generate Free ...      1
# 1  http://www.billboard.com/articles/columns/pop-...      1
# 2  Hey guys! Please join me in my fight to help a...      1
# 3  http://psnboss.com/?ref=2tGgp3pV6L this is the...      1
# 4  Hey everyone. Watch this trailer!!!!!!!!  http...      1

# %%
lmfao=pd.read_csv("Data/YouTubeSpamCollection_FromUCI/Youtube03-LMFAO.csv")
lmfao.head()
# Out:
#                               COMMENT_ID        AUTHOR  \
# 0  z13uwn2heqndtr5g304ccv5j5kqqzxjadmc0k  Corey Wilson
# 1  z124jvczaz3dxhnbc04cffk43oiugj25yzo0k   Epic Gaming
# 2      z13tczjy5xj0vjmu5231unho1ofey5zdk     LaS Music
# 3  z13tzr0hdpnayhqqc04cd3zqqqjkf3ngckk0k    Cheryl Fox
# 4  z12pcvix4zedcjvyb04ccr1r0mr2g5xwyng0k    PATRICK_TW
#
#                          DATE  \
# 0  2015-05-28T21:39:52.376000
# 1  2015-05-28T20:07:20.610000
# 2  2015-05-28T19:23:35.355000
# 3  2015-05-28T17:49:35.294000
# 4  2015-05-28T16:28:26.818000
#
#                                              CONTENT  CLASS
# 0  <a href="http://www.youtube.com/watch?v=KQ6zr6...      0
# 1                                   wierd but funny﻿      0
# 2  Hey guys, I&#39;m a human.<br /><br /><br />Bu...      1
# 3       Party Rock....lol...who wants to shuffle!!!﻿      0
# 4                                        Party rock﻿      0

# %%
eminem=pd.read_csv("Data/YouTubeSpamCollection_FromUCI/Youtube04-Eminem.csv")
eminem.head()
# Out:
#                             COMMENT_ID         AUTHOR  \
# 0    z12rwfnyyrbsefonb232i5ehdxzkjzjs2    Lisa Wellas
# 1  z130wpnwwnyuetxcn23xf5k5ynmkdpjrj04   jason graham
# 2    z13vsfqirtavjvu0t22ezrgzyorwxhpf3     Ajkal Khan
# 3  z12wjzc4eprnvja4304cgbbizuved35wxcs  Dakota Taylor
# 4    z13xjfr42z3uxdz2223gx5rrzs3dt5hna    Jihad Naser
#
#                          DATE  \
# 0                         NaN
# 1  2015-05-29T02:26:10.652000
# 2                         NaN
# 3  2015-05-29T02:13:07.810000
# 4                         NaN
#
#                                              CONTENT  CLASS
# 0          +447935454150 lovely girl talk to me xxx﻿      1
# 1    I always end up coming back to this song<br />﻿      0
# 2  my sister just received over 6,500 new <a rel=...      1
# 3                                              Cool﻿      0
# 4                     Hello I&#39;am from Palastine﻿      1

# %%
shakira=pd.read_csv("Data/YouTubeSpamCollection_FromUCI/Youtube05-Shakira.csv")
shakira.head()
# Out:
#                               COMMENT_ID                              AUTHOR  \
# 0    z13lgffb5w3ddx1ul22qy1wxspy5cpkz504                          dharma pal
# 1      z123dbgb0mqjfxbtz22ucjc5jvzcv3ykj                       Tiza Arellano
# 2  z12quxxp2vutflkxv04cihggzt2azl34pms0k  Prìñçeśś Âliś Łøvê Dømíñø Mâđiś™ ﻿
# 3      z12icv3ysqvlwth2c23eddlykyqut5z1h                       Eric Gonzalez
# 4      z133stly3kete3tly22petvwdpmghrlli                       Analena López
#
#                          DATE  \
# 0  2015-05-29T02:30:18.971000
# 1  2015-05-29T00:14:48.748000
# 2  2015-05-28T21:00:08.607000
# 3  2015-05-28T20:47:12.193000
# 4  2015-05-28T17:08:29.827000
#
#                                              CONTENT  CLASS
# 0                                         Nice song﻿      0
# 1                                      I love song ﻿      0
# 2                                      I love song ﻿      0
# 3  860,000,000 lets make it first female to reach...      0
# 4                      shakira is best for worldcup﻿      0

# %%
doc=pd.concat([psy,kp,lmfao,eminem,shakira],axis=0,ignore_index=True)
doc.shape
# Out:
# (1956, 5)

# %%
doc.head()
# Out:
#                                     COMMENT_ID            AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU         Julius NM
# 1  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 2  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 3          z13jhp0bxqncu512g22wvzkasxmvvzjaz04   ElNino Melendez
# 4          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw            GsMega
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 2  2013-11-08T17:34:21             just for test I have to say murdev.com
# 3  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 4  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# Total 1005 spams
doc['CLASS'].value_counts(normalize=True)
# Out:
# 1    0.513804
# 0    0.486196
# Name: CLASS, dtype: float64

# %%
def clean_text(text):
    nonpunc = [char for char in text if char not in string.punctuation]
    nonpunc = ''.join(nonpunc).lower()
    return[word for word in nonpunc.split() if word not in stopwords.words('english')]


class LemmaTokenizer(object):
    def __call__(self, text):
        return [lemma(t) for t in word_tokenize(text)]

# %%
# %%time
countVectorizer=CountVectorizer(decode_error='ignore',analyzer=clean_text,lowercase=False, tokenizer=LemmaTokenizer)
tfTransformer=TfidfTransformer()

xgb=XGBClassifier(max_depth=3,n_jobs=-1,n_estimators=40)

steps=[('countVectorizer',countVectorizer),
                    ('tfTransformer',tfTransformer),
                   ('xgb',xgb)]
pipe = Pipeline(steps)
# Out:
# Wall time: 0 ns

# %%
X_train=doc['CONTENT']
y_train=doc['CLASS']

pipe.fit(X_train,y_train);

# %%
test=pd.read_excel('Data/Comments.xlsx')

X_test=test['Comment'].astype('str')

predictions = pipe.predict(X_test)

test['Predictions']=pd.DataFrame(predictions)

# %%
filt=test['Predictions']==1
test.loc[filt,'Comment'].reset_index(drop=True)
# Out:
# 0     Do you like Taylor Swift?<br />Yes- Like<br />...
# 1     Imagine monetizing this video with adverts, cl...
# 2     Hey YOU! :) would you please listen to my terr...
# 3                                    Subscribe me plsss
# 4     Please increase my subscriber bcoz today is my...
# 5                       May channel open naw best video
# 6                  if you are alive, comment or like it
# 7     Who is better?<br /><br />Like: <b>Taylor Swif...
# 8              who is here for just to check the views👍
# 9                                   Mountain. Money. M.
# 10    How old are you can you come to Cornwall pleas...
# 11                  Who like my comment be a bellionair
# 12                       can someone like this comment?
# 13    Taylor stay amazing! Folks check out, Drag n J...
# 14     I&#39;m going to take the money of this vídeo :v
# 15    Who is better?<br /><br />Like: <b>Taylor Swif...
# 16    Fact: The car smashing scene is edited <br /><...
# 17    TAYLOR COME TO MY HOUSE PLEASE (you probably w...
# 18          Who just come to check the amout of viewers
# 19    <a href="https://www.youtube.com/watch?v=e-ORh...
# 20    Dear Math, please grow up and solve your own p...
# 21    Wheres the “I can make it back for your PlayDa...
# 22    2020 I want to be a Youtuber. Hope someone mak...
# 23    Who is better <br />Like Taylor<br />Comment T...
# 24    I wish i have money, i getting bore wanna do s...
# 25    I hate taylor for smashing that car. And dropp...
# 26    Please, you can follow up or subscribe, and I ...
# 27    If you&#39;re listening in December 2019 and f...
# 28    Faze fake said to comment ariana grande so Ari...
# 29    I always listen to this song its my favorite.....
# 30    Who is better?<br /><br />Like: <b>Taylor Swif...
# 31                                           2019 check
# 32               Please don&#39;t be like Taylor Swift.
# 33    If you&#39;re see this comment and you don&#39...
# 34    Who is better?<br /><br />Like: <b>Taylor Swif...
# 35    I love Fantasizing about her. Please message m...
# 36    is that Brendon Urie? please dont call me weir...
# 37    Can we please get rid of the &quot;crazy women...
# 38               Can please come to India to do concert
# 39            Awesome video please watch my new video 😀
# 40    Who hears this song because of the clicks 😑 pl...
# 41    I SEARCH NICK JONAS AND THIS POPPED OUT PLEASE...
# 42    Who here thinks gacha studio/life kids are as ...
# 43    i hope that was not real blood ok please tell ...
# 44    Who is here after Amas 2019 Artist of the deca...
# 45           When will this get old? Please tell me.😂😂😂
# 46    Please tell me this isn’t real if it is why di...
# 47          Taylor, please make blank space lyric video
# 48    Who Is Better?<br /><br />Like: <b>Taylor Swif...
# 49    Shepherd from CODMW2 : AND I&#39;VE GOT A BLAN...
# 50    Who Is Better?<br /><br />Like: <b>Taylor Swif...
# 51    Can people please stop making comments just fo...
# 52                                     please subscribe
# 53            People who don&#39;t have  a lot of money
# Name: Comment, dtype: object
